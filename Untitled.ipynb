# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('NFA 2019 public_data.csv')
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10280\3661665428.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('NFA 2019 public_data.csv')
#        country  year  country_code        record     crop_land  grazing_land  \
# 0      Armenia  1992             1    AreaPerCap  1.402924e-01  1.995463e-01
# 1      Armenia  1992             1     AreaTotHA  4.830000e+05  6.870000e+05
# 2      Armenia  1992             1  BiocapPerCap  1.598044e-01  1.352610e-01
# 3      Armenia  1992             1  BiocapTotGHA  5.501762e+05  4.656780e+05
# 4      Armenia  1992             1  EFConsPerCap  3.875102e-01  1.894622e-01
# ...        ...   ...           ...           ...           ...           ...
# 72181    World  2016          5001  BiocapTotGHA  3.984702e+09  1.504757e+09
# 72182    World  2016          5001  EFConsPerCap  5.336445e-01  1.402092e-01
# ...

# %%
df.dropna(inplace=True)
df.corr()
# Out:
#                     year  country_code  crop_land  grazing_land  \
# year            1.000000     -0.008143   0.016055     -0.006312
# country_code   -0.008143      1.000000   0.642240      0.592193
# crop_land       0.016055      0.642240   1.000000      0.722896
# grazing_land   -0.006312      0.592193   0.722896      1.000000
# fishing_ground -0.004076      0.528693   0.612383      0.965757
# built_up_land   0.035558      0.577763   0.963471      0.654255
# carbon          0.019156      0.446023   0.764573      0.338858
# total           0.009060      0.657821   0.965973      0.816314
#
#                 fishing_ground  built_up_land    carbon     total
# year                 -0.004076       0.035558  0.019156  0.009060
# country_code          0.528693       0.577763  0.446023  0.657821
# crop_land             0.612383       0.963471  0.764573  0.965973
# grazing_land          0.965757       0.654255  0.338858  0.816314
# ...

# %%
X=df['crop_land','grazing_land']
y=df['built_up_land']

# %%
lm=LinearRegression()
model=lm.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 lm=LinearRegression()
# ----> 2 model=lm.fit(X,y)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# ...

# %%
built_up_land_predict=model.predict()
plt.figure(figsize=(12,6))
plt.plot(df['crop_land'],df['built_up_land'],'o')
plt.plot(df['crop_land'],built_up_land_predict,'r',linewidth=2)
plt.xlabel('cropland')
plt.ylabel('builtland')
plt.title('builtland vs cropland')
plt.show()
